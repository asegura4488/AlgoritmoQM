# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/AlgoritmoQM/blob/main/Semana3/Tarea_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from google.colab import files
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir("/content/drive/MyDrive/cienciaDatos/Semana3")
# !pwd
# Out:
# /content/drive/MyDrive/cienciaDatos/Semana3

# %%
df = pd.read_csv("datos/muestra.csv")

# %%
#Vamos a explorar las llaves de la hoja de calculo
#Los metodos terminan en () y los atributos o variables no tienen ()
#Los metodos, son funciones que actuan sobre los objetos
#df.shape - indica el tamaño que tiene el data frame
df.keys()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   fecha reporte web             300 non-null    object
#  1   ID de caso                    300 non-null    object
#  2   Fecha de notificación         300 non-null    object
#  3   Código DIVIPOLA departamento  300 non-null    object
#  4   Nombre departamento           300 non-null    object
#  5   Código DIVIPOLA municipio     300 non-null    object
#  6   Nombre municipio              300 non-null    object
#  7   Edad                          300 non-null    int64
#  8   Unidad de medida de edad      300 non-null    int64
#  9   Sexo                          300 non-null    object
#  10  Tipo de contagio              300 non-null    object
#  11  Ubicación del caso            298 non-null    object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
####TAREA 2
# !pwd
# 1. Usando algún archivo de la base de datos de Covid, agrupar por genero, después, calcular la distribución de edad

for genero, i in df.groupby('Sexo'):
  edades = i['Edad']
#Construccion del histograma para cada genero
  #plt.figure (figsize=(3,3) )
  #edades.plot.hist( alpha=0.5, label=genero )
  #plt.legend()
# 2. y guardar el gráfico en dos carpetas distintas. Una carpeta para masculino y otra para femenino.
  folder=os.makedirs(genero,exist_ok=True) # No entiendo cuando crea las carpetas
  print(folder)

  outpath=os.path.join(genero,f"hist_{genero}.pdf")
  print(outpath)
  plt.figure (figsize=(3,3) )
  edades.plot.hist( alpha=0.5, label=genero )
  plt.legend()
  #Aca guardamos la imagen
  plt.savefig(outpath)
  plt.close()
# Out:
# /content/drive/MyDrive/cienciaDatos/Semana3
# None
# F/hist_F.pdf
# None
# M/hist_M.pdf
